# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ruta = '../data/raw/patient_churn_dataset.csv'
data = pd.read_csv(ruta)
data.head()
# Out:
#   PatientID  Age  Gender State  Tenure_Months          Specialty  \
# 0    C20000   41  Female    PA             62         Pediatrics
# 1    C20001   43  Female    GA             44  Internal Medicine
# 2    C20002   21    Male    MI            120  Internal Medicine
# 3    C20003   65    Male    FL            118   General Practice
# 4    C20004   18  Female    CA             70         Cardiology
#
#   Insurance_Type  Visits_Last_Year  Missed_Appointments  \
# 0       Medicaid                 1                    0
# 1       Self-Pay                 7                    4
# 2       Medicaid                15                    5
# 3        Private                10                    3
# 4       Medicaid                 5                    4
#
#    Days_Since_Last_Visit  ... Overall_Satisfaction  Wait_Time_Satisfaction  \
# 0                    564  ...                  3.5                     4.9
# 1                    254  ...                  2.6                     3.1
# 2                     89  ...                  1.6                     4.4
# 3                    135  ...                  2.6                     4.3
# 4                    696  ...                  2.2                     4.0
#
#    Staff_Satisfaction  Provider_Rating  Avg_Out_Of_Pocket_Cost  \
# 0                 3.8              4.2                     306
# 1                 4.7              4.3                    1851
# 2                 2.1              4.7                     391
# 3                 4.3              4.9                     808
# 4                 4.1              4.4                     866
#
#    Billing_Issues  Portal_Usage  Referrals_Made  Distance_To_Facility_Miles  \
# 0               0             0               3                        21.4
# 1               0             0               0                        47.6
# 2               0             0               2                         7.1
# 3               0             0               0                        11.6
# 4               0             0               0                        10.3
#
#    Churned
# 0        1
# 1        1
# 2        0
# 3        1
# 4        1
#
# [5 rows x 21 columns]

# %%
data.describe()
# Out:
#                Age  Tenure_Months  Visits_Last_Year  Missed_Appointments  \
# count  2000.000000    2000.000000       2000.000000          2000.000000
# mean     52.856500      60.733500          7.614000             2.028000
# std      15.836487      35.111293          4.672143             1.699312
# min      18.000000       1.000000          0.000000             0.000000
# 25%      41.000000      30.000000          4.000000             0.000000
# 50%      54.000000      60.000000          8.000000             2.000000
# 75%      65.000000      92.250000         12.000000             3.000000
# max      90.000000     120.000000         15.000000             5.000000
#
#        Days_Since_Last_Visit  Overall_Satisfaction  Wait_Time_Satisfaction  \
# count            2000.000000           2000.000000             2000.000000
# mean              366.130000              3.255000                3.289900
# std               212.890277              1.008595                1.009062
# min                 1.000000              1.500000                1.500000
# 25%               180.000000              2.400000                2.400000
# 50%               363.000000              3.200000                3.300000
# 75%               550.250000              4.100000                4.100000
# max               730.000000              5.000000                5.000000
#
#        Staff_Satisfaction  Provider_Rating  Avg_Out_Of_Pocket_Cost  \
# count         2000.000000      2000.000000             2000.000000
# mean             3.525900         3.736100              836.544000
# std              0.871613         0.733748              589.031896
# min              2.000000         2.500000               20.000000
# 25%              2.775000         3.100000              326.000000
# 50%              3.500000         3.800000              716.000000
# 75%              4.300000         4.400000             1368.250000
# max              5.000000         5.000000             1999.000000
#
#        Billing_Issues  Portal_Usage  Referrals_Made  \
# count     2000.000000   2000.000000     2000.000000
# mean         0.078500      0.206000        1.483500
# std          0.269024      0.404532        1.100151
# min          0.000000      0.000000        0.000000
# 25%          0.000000      0.000000        1.000000
# 50%          0.000000      0.000000        1.000000
# 75%          0.000000      0.000000        2.000000
# max          1.000000      1.000000        3.000000
#
#        Distance_To_Facility_Miles      Churned
# count                 2000.000000  2000.000000
# mean                    25.167400     0.683500
# std                     13.948284     0.465227
# min                      0.500000     0.000000
# 25%                     12.800000     0.000000
# 50%                     25.000000     1.000000
# 75%                     37.200000     1.000000
# max                     50.000000     1.000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PatientID                   2000 non-null   object
#  1   Age                         2000 non-null   int64
#  2   Gender                      2000 non-null   object
#  3   State                       2000 non-null   object
#  4   Tenure_Months               2000 non-null   int64
#  5   Specialty                   2000 non-null   object
#  6   Insurance_Type              2000 non-null   object
#  7   Visits_Last_Year            2000 non-null   int64
#  8   Missed_Appointments         2000 non-null   int64
#  9   Days_Since_Last_Visit       2000 non-null   int64
#  10  Last_Interaction_Date       2000 non-null   object
#  11  Overall_Satisfaction        2000 non-null   float64
#  12  Wait_Time_Satisfaction      2000 non-null   float64
#  13  Staff_Satisfaction          2000 non-null   float64
#  14  Provider_Rating             2000 non-null   float64
#  15  Avg_Out_Of_Pocket_Cost      2000 non-null   int64
#  16  Billing_Issues              2000 non-null   int64
#  17  Portal_Usage                2000 non-null   int64
#  18  Referrals_Made              2000 non-null   int64
#  19  Distance_To_Facility_Miles  2000 non-null   float64
#  20  Churned                     2000 non-null   int64
# dtypes: float64(5), int64(10), object(6)
# memory usage: 328.3+ KB

# %% [markdown]
# ### Variables numéricas

# %%
numeric_cols = data.select_dtypes(include=['int64', 'float64']).columns.tolist()
n_vars = len(numeric_cols)
n_cols = 4
n_rows = (n_vars + n_cols - 1) // n_cols

fig, axes = plt.subplots(n_rows, n_cols, figsize=(20, n_rows * 4))

if n_rows == 1:
    axes = axes.reshape(1, -1)
elif n_cols == 1:
    axes = axes.reshape(-1, 1)

for idx, col in enumerate(numeric_cols):
    row_idx = idx // n_cols
    col_idx = idx % n_cols
    
    ax = axes[row_idx, col_idx]
    
    # Histograma con KDE
    sns.histplot(data[col], kde=True, ax=ax, bins=30, 
                 color='steelblue', edgecolor='black', alpha=0.7)
    
    # Calcular estadísticas
    stats = {
        'mean': data[col].mean(),
        'median': data[col].median(),
        'std': data[col].std(),
        'skew': data[col].skew()
    }
    
    # Añadir líneas
    ax.axvline(stats['mean'], color='red', linestyle='--', linewidth=2, 
               alpha=0.8, label=f"μ={stats['mean']:.2f}")
    ax.axvline(stats['median'], color='green', linestyle=':', linewidth=2,
               alpha=0.8, label=f"med={stats['median']:.2f}")
    
    # Colorear título según skewness
    skew_color = 'red' if abs(stats['skew']) > 1 else 'orange' if abs(stats['skew']) > 0.5 else 'green'
    
    ax.set_title(f'{col}\nskew={stats["skew"]:.2f}', fontsize=11, 
                 fontweight='bold', color=skew_color)
    ax.set_xlabel('')
    ax.set_ylabel('Densidad', fontsize=9)
    ax.legend(fontsize=8)
    ax.grid(True, alpha=0.3)

# Ocultar ejes vacíos
for idx in range(n_vars, n_rows * n_cols):
    row_idx = idx // n_cols
    col_idx = idx % n_cols
    axes[row_idx, col_idx].set_visible(False)

plt.suptitle('DISTRIBUCIÓN CON KDE DE TODAS LAS VARIABLES NUMÉRICAS', 
             fontsize=18, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# %%
# Variables realmente categoricas
real_ordinal_cols = ['Referrals_Made', 'Staff_Satisfaction']
real_nominal_cols = ['Billing_Issues', 'Portal_Usage']

# %%
# Feature engineering

data['frecuencia_visitas'] = data['Visits_Last_Year'] / 12
data['ratio_citas_perdidas'] = data['Missed_Appointments'] / data['Visits_Last_Year']
data['costoxvisita'] = data['Avg_Out_Of_Pocket_Cost'] / data['Visits_Last_Year']    

eliminar_numericas = ['Visits_Last_Year', 'Missed_Appointments', 'Avg_Out_Of_Pocket_Cost']    
data.drop(columns = eliminar_numericas, inplace = True)

# %%
numericas = data.select_dtypes(include = 'number').columns.to_list()
numericas_final = [col for col in numericas if col not in real_nominal_cols and col not in real_ordinal_cols]
numericas_final.remove('Churned')
numericas_final.append('Churned')   
numericas_final
# Out:
# ['Age',
#  'Tenure_Months',
#  'Days_Since_Last_Visit',
#  'Overall_Satisfaction',
#  'Wait_Time_Satisfaction',
#  'Provider_Rating',
#  'Distance_To_Facility_Miles',
#  'frecuencia_visitas',
#  'ratio_citas_perdidas',
#  'costoxvisita',
#  'Churned']

# %%
corr_matrix = data[numericas_final].corr()
plt.figure(figsize=(12, 10))
mask = np.triu(np.ones_like(corr_matrix, dtype=bool))
sns.heatmap(corr_matrix, mask=mask, annot=True, fmt='.2f', 
            cmap='coolwarm', center=0, square=True, edgecolor='white', linewidths=0.9)
plt.title('Matriz de Correlación')
plt.show()

# Cuando la frecuencia de visitas sube, el costoxvisita baja porque van a citas mas baratas
# Cuando la frecuencia de visitas sube, el ratio de citas perdidas baja 
# Cuando la edad sube, el churned baja, lo que sugiere que los pacientes mayores son menos propensos a abandonar el servicio
# Cuando el overall_satisfaction sube el churned baja, lo que indica que los pacientes más satisfechos tienen menos probabilidades de abandonar el servicio

# %% [markdown]
# ### Variables categóricas

# %%
categoricas = data.select_dtypes(include = 'object').columns.to_list()
categoricas.extend(real_ordinal_cols + real_nominal_cols)
categoricas

for cat in categoricas:
    if cat != 'PatientID':
        print(f'Categoria: {cat}')
        print(data[cat].value_counts())
        print('-'*40)
# Out:
# Categoria: Gender
# Gender
# Male      1016
# Female     984
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: State
# State
# NC    259
# IL    214
# FL    213
# PA    205
# NY    197
# OH    193
# CA    184
# GA    181
# TX    180
# MI    174
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: Specialty
# Specialty
# General Practice     302
# Family Medicine      289
# Orthopedics          289
# Neurology            286
# Pediatrics           284
# Internal Medicine    277
# Cardiology           273
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: Insurance_Type
# Insurance_Type
# Self-Pay    523
# Medicare    516
# Private     483
# Medicaid    478
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: Last_Interaction_Date
# Last_Interaction_Date
# 2025-05-01    11
# 2025-04-18     8
# 2025-05-11     8
# 2025-08-21     8
# 2025-02-18     8
#               ..
# 2025-05-21     1
# 2024-12-28     1
# 2024-11-19     1
# 2024-04-02     1
# 2026-01-19     1
# Name: count, Length: 679, dtype: int64
# ----------------------------------------
# Categoria: Referrals_Made
# Referrals_Made
# 1    544
# 2    496
# 0    483
# 3    477
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: Staff_Satisfaction
# Staff_Satisfaction
# 4.6    79
# 3.2    77
# 4.7    77
# 4.4    77
# 4.3    77
# 2.9    76
# 2.7    72
# 4.0    72
# 4.5    71
# 2.2    70
# 3.1    70
# 3.9    69
# 2.3    69
# 2.6    69
# 4.8    68
# 4.1    67
# 2.5    67
# 3.7    65
# 3.8    64
# 4.2    63
# 2.4    63
# 3.5    61
# 3.4    61
# 3.6    58
# 4.9    58
# 2.1    58
# 3.3    55
# 2.8    53
# 3.0    49
# 5.0    33
# 2.0    32
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: Billing_Issues
# Billing_Issues
# 0    1843
# 1     157
# Name: count, dtype: int64
# ----------------------------------------
# Categoria: Portal_Usage
# Portal_Usage
# 0    1588
# 1     412
# Name: count, dtype: int64
# ----------------------------------------

# %%
eliminar_categoricas = ['PatientID', 'Last_Interaction_Date']
data.drop(columns = eliminar_categoricas, inplace=True)
data.head()
# Out:
#    Age  Gender State  Tenure_Months          Specialty Insurance_Type  \
# 0   41  Female    PA             62         Pediatrics       Medicaid
# 1   43  Female    GA             44  Internal Medicine       Self-Pay
# 2   21    Male    MI            120  Internal Medicine       Medicaid
# 3   65    Male    FL            118   General Practice        Private
# 4   18  Female    CA             70         Cardiology       Medicaid
#
#    Days_Since_Last_Visit  Overall_Satisfaction  Wait_Time_Satisfaction  \
# 0                    564                   3.5                     4.9
# 1                    254                   2.6                     3.1
# 2                     89                   1.6                     4.4
# 3                    135                   2.6                     4.3
# 4                    696                   2.2                     4.0
#
#    Staff_Satisfaction  Provider_Rating  Billing_Issues  Portal_Usage  \
# 0                 3.8              4.2               0             0
# 1                 4.7              4.3               0             0
# 2                 2.1              4.7               0             0
# 3                 4.3              4.9               0             0
# 4                 4.1              4.4               0             0
#
#    Referrals_Made  Distance_To_Facility_Miles  Churned  frecuencia_visitas  \
# 0               3                        21.4        1            0.083333
# 1               0                        47.6        1            0.583333
# 2               2                         7.1        0            1.250000
# 3               0                        11.6        1            0.833333
# 4               0                        10.3        1            0.416667
#
#    ratio_citas_perdidas  costoxvisita
# 0              0.000000    306.000000
# 1              0.571429    264.428571
# 2              0.333333     26.066667
# 3              0.300000     80.800000
# 4              0.800000    173.200000

# %% [markdown]
# ## Cardinalidad de las clases

# %%
min = data['Churned'].value_counts().min()
max = data['Churned'].value_counts().max()
print(f'Imbalance ratio: {np.round((max / min), 4)}')

data['Churned'].value_counts().plot(title= 'Cardinalidad', kind='bar', color=['skyblue', 'salmon'], edgecolor='black')
# Out:
# Imbalance ratio: 2.1596
# <Axes: title={'center': 'Cardinalidad'}, xlabel='Churned'>

# %% [markdown]
# ## Datos limpios

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 19 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         2000 non-null   int64
#  1   Gender                      2000 non-null   object
#  2   State                       2000 non-null   object
#  3   Tenure_Months               2000 non-null   int64
#  4   Specialty                   2000 non-null   object
#  5   Insurance_Type              2000 non-null   object
#  6   Days_Since_Last_Visit       2000 non-null   int64
#  7   Overall_Satisfaction        2000 non-null   float64
#  8   Wait_Time_Satisfaction      2000 non-null   float64
#  9   Staff_Satisfaction          2000 non-null   float64
#  10  Provider_Rating             2000 non-null   float64
#  11  Billing_Issues              2000 non-null   int64
#  12  Portal_Usage                2000 non-null   int64
#  13  Referrals_Made              2000 non-null   int64
#  14  Distance_To_Facility_Miles  2000 non-null   float64
#  15  Churned                     2000 non-null   int64
#  16  frecuencia_visitas          2000 non-null   float64
#  17  ratio_citas_perdidas        1881 non-null   float64
#  18  costoxvisita                2000 non-null   float64
# dtypes: float64(8), int64(7), object(4)
# memory usage: 297.0+ KB

# %%
caracteristicas_final = data.columns.to_list()
caracteristicas_final.remove('Churned')
caracteristicas_final.append('Churned')
data = data[caracteristicas_final]
data.head()
# Out:
#    Age  Gender State  Tenure_Months          Specialty Insurance_Type  \
# 0   41  Female    PA             62         Pediatrics       Medicaid
# 1   43  Female    GA             44  Internal Medicine       Self-Pay
# 2   21    Male    MI            120  Internal Medicine       Medicaid
# 3   65    Male    FL            118   General Practice        Private
# 4   18  Female    CA             70         Cardiology       Medicaid
#
#    Days_Since_Last_Visit  Overall_Satisfaction  Wait_Time_Satisfaction  \
# 0                    564                   3.5                     4.9
# 1                    254                   2.6                     3.1
# 2                     89                   1.6                     4.4
# 3                    135                   2.6                     4.3
# 4                    696                   2.2                     4.0
#
#    Staff_Satisfaction  Provider_Rating  Billing_Issues  Portal_Usage  \
# 0                 3.8              4.2               0             0
# 1                 4.7              4.3               0             0
# 2                 2.1              4.7               0             0
# 3                 4.3              4.9               0             0
# 4                 4.1              4.4               0             0
#
#    Referrals_Made  Distance_To_Facility_Miles  frecuencia_visitas  \
# 0               3                        21.4            0.083333
# 1               0                        47.6            0.583333
# 2               2                         7.1            1.250000
# 3               0                        11.6            0.833333
# 4               0                        10.3            0.416667
#
#    ratio_citas_perdidas  costoxvisita  Churned
# 0              0.000000    306.000000        1
# 1              0.571429    264.428571        1
# 2              0.333333     26.066667        0
# 3              0.300000     80.800000        1
# 4              0.800000    173.200000        1

# %%
cleaned_data = data.copy()
cleaned_data.to_csv('../data/processed/cleaned_patient_churn_dataset.csv', index=False)
